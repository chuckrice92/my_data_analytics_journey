# %% [markdown]
# # Declaration of Variables

# %%
integer = 3

# %%
print(integer)
# Out:
# 3

# %%
type(integer)
# Out:
# int

# %%
float = 5.3

# %%
print(float)
# Out:
# 5.3

# %%
type(float)
# Out:
# float

# %%
string = "charles"

# %%
print(string)
# Out:
# charles

# %%
type("charles")
# Out:
# str

# %%
boolean = True

# %%
10 > 5
# Out:
# True

# %%
print(boolean)
# Out:
# True

# %%
type(boolean)
# Out:
# bool

# %% [markdown]
# # Manipulating String Code

# %%
Example = "Python basics"

# %%
print(Example.lower())
# Out:
# python basics

# %%
print(Example.upper())
# Out:
# PYTHON BASICS

# %%
print(Example.split(","))
# Out:
# ['Python basics']

# %% [markdown]
# # Basic Operations

# %% [markdown]
# ## Arithmetic

# %%
a,b = 2,3

# %%
print(a+b, a-b)
# Out:
# 5 -1

# %%
print(a*b, a/b)
# Out:
# 6 0.6666666666666666

# %%
print(a^b)
# Out:
# 1

# %%
print(a**b)
# Out:
# 8

# %% [markdown]
# ## Comparison

# %%
print(a>b,a<b)
# Out:
# False True

# %%
print(a==b,a!=b)
# Out:
# False True

# %%
print(a<=b,a>=b)
# Out:
# True False

# %% [markdown]
# ## Logical

# %%
print(a>4 and b<4)
# Out:
# False

# %%
print(a<=4 or b>=4)
# Out:
# True

# %%
print(a<4, not 4==b)
# Out:
# True True

# %% [markdown]
# # Data Collections

# %%
my_list = [100,115,141,151,187]

# %%
my_dict = {"Charles":"Rice","John":"Smith","Keith":"Richards"}

# %%
my_tup = ("Charles",33,"Rice")

# %%
print(my_list[3])
# Out:
# 151

# %%
print(my_dict["Charles"])
# Out:
# Rice

# %%
print(my_tup[2])
# Out:
# Rice

# %% [markdown]
# # Expression Combination

# %%
result = ((a+b)/float)+len(my_list)

# %%
print(result)
# Out:
# 5.943396226415095
